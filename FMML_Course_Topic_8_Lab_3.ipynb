# %% [markdown]
# <a href="https://colab.research.google.com/github/Durga9704/fmml-assessments/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-02 06:51:59--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   376MB/s    in 0.2s
#
# 2023-05-02 06:52:00 (376 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 22766  1706.02326v2  In this paper, we propose a new volume-preserv...  stat
# 23160   0805.3964v2  Feature selection is a pattern recognition app...    cs
# 6919   1707.06145v1  Tissue characterization has long been an impor...    cs
# 2562   1605.04135v3  The estimation of class prevalence, i.e., the ...  stat
# 36321   1206.5280v1  Ranking objects is a simple and natural proced...    cs
# ...             ...                                                ...   ...
# 37845   0809.4178v2  Approximate Bayesian inference on the basis of...  stat
# 13     1604.01662v2  While perception tasks such as visual object r...  stat
# 18630   1106.4569v1  Despite the significant progress in multiagent...    cs
# 2779   1711.09268v3  We present a general-purpose method to train M...  stat
# 22102   1411.4378v1  While robust parameter estimation has been wel...  stat
#
#                                                    title  year  \
# 22766  Improving Variational Auto-Encoders using conv...  2017
# 23160  DimReduction - Interactive Graphic Environment...  2008
# 6919   Self-paced Convolutional Neural Network for Co...  2017
# 2562   Online Optimization Methods for the Quantifica...  2016
# 36321                          Ranking Under Uncertainty  2012
# ...                                                  ...   ...
# 37845  Non-linear regression models for Approximate B...  2008
# 13              Towards Bayesian Deep Learning: A Survey  2016
# 18630  The Communicative Multiagent Team Decision Pro...  2011
# 2779   Generalizing Hamiltonian Monte Carlo with Neur...  2017
# 22102  Robust Kernel Density Estimation by Scaling an...  2014
#
#                                                 keywords
# 22766  [preserving, similarly, normalizing, autoregre...
# 23160  [selection, recognition, important, variables,...
# 6919   [characterization, important, component, diagn...
# 2562   [estimation, prevalence, population, analytics...
# 36321  [procedure, organizing, performed, assigning, ...
# ...                                                  ...
# 37845  [approximate, inference, statistics, likelihoo...
# 13     [perception, recognition, understanding, impor...
# 18630  [significant, multiagent, optimality, prescrip...
# 2779   [parameterized, distribution, generalizes, ham...
# 22102  [parameter, estimation, parametric, estimation...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 22766    [preserving, similarly, normalizing, autoregre...
# 23160    [selection, recognition, important, variables,...
# 6919     [characterization, important, component, diagn...
# 2562     [estimation, prevalence, population, analytics...
# 36321    [procedure, organizing, performed, assigning, ...
#                                ...
# 16852    [introduces, framework, including, prediction,...
# 6632     [professional, applications, complicated, impr...
# 6361     [ensembles, prediction, interpretability, inte...
# 2480     [important, performance, applications, imbalan...
# 22726    [representing, classification, constructed, si...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8743 words.
# Out of those 4555 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="234a851a-e0ae-4f91-b3e8-168369525944" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("234a851a-e0ae-4f91-b3e8-168369525944")) {                    Plotly.newPlot(                        "234a851a-e0ae-4f91-b3e8-168369525944",                        [{"x":["combining","preserving","introducing","experimental","improving","histopathology","triangular","autoregressive","outperforms","competitive","normalizing","variational","similarly","combination","reduction","inference","difficult","environment","variables","biological","informative","recurrent","algorithms","criterion","according","graphical","signature","bioinformatics","selecting","dimensionality","approaches","applications","probabilities","important","selection","interactive","distinguish","questions","functions","phenomena","recognition","prediction","consuming","expensive","performance","heterogeneity","tomography","component","unlabeled","characterization","annotation","automatic","including","consistently","diagnosis","indicates","motivated","detection","challenging","instances","convolutional","development","specifically","computing","utilizing","contribution","implementing","outperformed","increasing","framework","analytics","contemporary","quantification","objective","multivariate","demonstrate","benchmark","performing","advancement","convergence","estimator","literature","outperform","estimators","sentiments","theoretical","optimizing","extensive","supervised","experiments","stochastic","prevalence","distribution","significantly","population","epidemiology","techniques","estimation","classification","optimization","sentiment","significant","analytical","experiment","simulations","situations","evaluation","influence","necessary","reliability","organizing","available","attaining","uncertainty","similarity","assigning","calculated","introduce","assessing","microarray","relevance","currently","reasonably","procedure","processing","measurements","performed","sensitive","resources","contextual","generative","simultaneously","particular","algorithm","interaction","biomedical","interpretable","maximization","exploration","approximate","information","calculate","parameters","interactions","developed","approximations","application","exploitation","distributions","reinforcement","dependent","limitations","complexity","engineering","properties","facilitates","sequentially","community","optimality","modifications","partially","convexity","numerical","characterised","inequality","intervals","described","constraints","additional","considered","reconstruction","deblurring","imperfect","practically","fingerprints","factorization","measurement","injection","dimensional","therefore","characterized","incorporate","researchers","specially","interested","understanding","different","compounds","separating","overcoming","conducting","representative","solutions","competitively","computational","seriously","carefully","implementation","additionally","modification"],"y":[109,55,48,420,94,4,2,2,254,101,4,57,19,136,112,223,146,112,116,52,40,137,551,45,119,57,16,8,44,51,458,438,62,394,155,45,25,62,235,26,363,218,34,61,904,10,17,103,39,26,66,208,271,41,55,24,47,364,254,86,337,139,145,121,42,77,22,26,95,514,14,13,12,159,28,551,171,63,7,111,27,127,87,15,10,154,47,166,199,560,126,6,221,264,49,2,363,183,538,279,51,239,19,79,45,47,241,57,68,26,17,293,3,81,144,22,33,294,12,4,41,54,9,115,297,56,125,62,73,49,108,116,271,760,95,18,29,37,60,121,692,17,232,91,221,23,272,25,124,124,73,67,231,50,225,20,21,68,24,19,40,5,76,5,9,9,74,128,115,151,88,6,8,15,8,36,33,2,178,137,26,69,71,10,20,169,739,1,13,10,8,36,126,5,290,3,33,142,72,27],"type":"bar"},{"x":["combining","preserving","introducing","experimental","improving" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4555,), (4555, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8175

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Deep</span> <span style=''>Bayesian</span> <span style=''>Active</span> <span style=''>Semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Supervised</span> <span style=''>Learning</span> <br/><br/><span style=''>In</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>the</span> <span style=''>process</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3006134969325154);'>generating</span> <span style=''>label</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>expensive</span> <span style=''>and</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333326);'>consuming</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style=''>new</span> <span style=''>method</span> <span style=''>that</span> <span style=''>combines</span> <span style=''>active</span> <span style=''>and</span> <span style=''>semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>to</span> <span style=''>achieve</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generalization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>from</span> <span style=''>a</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.5638051044083527);'>convolutional</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>with</span> <span style=''>as</span> <span style=''>few</span> <span style=''>known</span> <span style=''>labels</span> <span style=''>as</span> <span style=''>possible</span> <span style=''>In</span> <span style=''>a</span> <span style=''>setting</span> <span style=''>where</span> <span style=''>a</span> <span style=''>small</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>as</span> <span style=''>well</span> <span style=''>as</span> <span style=''>a</span> <span style=''>large</span> <span style=''>amount</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unlabeled</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>our</span> <span style=''>method</span> <span style=''>first</span> <span style=''>learns</span> <span style=''>the</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>set</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3191489361702127);'>initialization</span> <span style=''>is</span> <span style=''>followed</span> <span style=''>by</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3469387755102041);'>expectation</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maximization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>where</span> <span style=''>further</span> <span style=''>training</span> <span style=''>reduces</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>entropy</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unlabeled</span> <span style=''>data</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>targeting</span> <span style=''>a</span> <span style=''>low</span> <span style=''>entropy</span> <span style=''>fit</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>with</span> <span style=''>the</span> <span style=''>labeled</span>  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Group</span> <span style=''>Symmetry</span> <span style=''>and</span> <span style=''>non</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Covariance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Estimation</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style=''>robust</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>with</span> <span style=''>group</span> <span style=''>symmetry</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>Non</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>eg</span> <span style=''>Tyler</span> <span style=''>scatter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimator</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Multivariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalized</span> <span style=''>Gaussian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>methods</span> <span style=''>usually</span> <span style=''>involve</span> <span style=''>non</span> <span style=''>convex</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>problems</span> <span style=''>Recently</span> <span style=''>it</span> <span style=''>was</span> <span style=''>shown</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principle</span> <span style=''>behind</span> <span style=''>their</span> <span style=''>success</span> <span style=''>is</span> <span style=''>an</span> <span style=''>extended</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convexity</span> <span style=''>over</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>geodesics</span> <span style=''>in</span> <span style=''>the</span> <span style=''>manifold</span> <span style=''>of</span> <span style=''>positive</span> <span style=''>definite</span> <span style=''>matrices</span> <span style=''>A</span> <span style=''>modern</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>improve</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>accuracy</span> <span style=''>is</span> <span style=''>to</span> <span style=''>exploit</span> <span style=''>prior</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>via</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>additional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>eg</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restricting</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attention</span> <span style=''>to</span> <span style=''>specific</span> <span style=''>classes</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariances</span> <span style=''>which</span> <span style=''>adhere</span> <span style=''>to</span> <span style=''>prior</span> <span style=''>symmetry</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>such</span> <span style=''>group</span> <span style=''>symmetry</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constraints</span> <span style=''>are</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Practical</span> <span style='background-color:rgba(255, 0, 0, 0.8461538461538461);'>Collapsed</span> <span style='background-color:rgba(255, 0, 0, 0.37623762376237624);'>Stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.544);'>Variational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Inference</span> <span style=''>for</span> <span style=''>the</span> <span style=''>HDP</span> <br/><br/><span style=''>Recent</span> <span style=''>advances</span> <span style=''>have</span> <span style=''>made</span> <span style=''>it</span> <span style=''>feasible</span> <span style=''>to</span> <span style=''>apply</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.37623762376237624);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.544);'>variational</span> <span style=''>paradigm</span> <span style=''>to</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.8461538461538461);'>collapsed</span> <span style='background-color:rgba(0, 255, 0, 0.41758241758241765);'>representation</span> <span style=''>of</span> <span style=''>latent</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>Dirichlet</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>allocation</span> <span style=''>(LDA)</span> <span style=''>While</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.37623762376237624);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.544);'>variational</span> <span style=''>paradigm</span> <span style=''>has</span> <span style='background-color:rgba(0, 255, 0, 0.3237410071942446);'>successfully</span> <span style=''>been</span> <span style=''>applied</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333326);'>uncollapsed</span> <span style='background-color:rgba(0, 255, 0, 0.41758241758241765);'>representation</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(255, 0, 0, 0.5);'>Dirichlet</span> <span style=''>process</span> <span style=''>(HDP)</span> <span style=''>no</span> <span style=''>attempts</span> <span style=''>to</span> <span style=''>apply</span> <span style=''>this</span> <span style=''>type</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.8461538461538461);'>collapsed</span> <span style=''>setting</span> <span style=''>of</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.5172413793103449);'>parametric</span> <span style=''>topic</span> <span style=''>modeling</span> <span style=''>have</span> <span style=''>been</span> <span style=''>put</span> <span style=''>forward</span> <span style=''>so</span> <span style=''>far</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>explore</span> <span style=''>such</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.8461538461538461);'>collapsed</span> <span style='background-color:rgba(255, 0, 0, 0.37623762376237624);'>stochastic</span> <span style='background-color:rgba(255, 0, 0, 0.544);'>variational</span> <span style=''>Bayes</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inference</span> <span style=''>for</span> <span style=''>the</span> <span style=''>HDP</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>online</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>is</span> <span style=''>easy</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implement</span> <span style=''>and</span> <span style=''>accounts ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Hyperparameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Importance</span> <span style=''>Across</span> <span style=''>Datasets</span> <br/><br/><span style=''>With</span> <span style=''>the</span> <span style=''>advent</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automated</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>by</span> <span style=''>now</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>routinely</span> <span style=''>used</span> <span style=''>However</span> <span style=''>this</span> <span style=''>progress</span> <span style=''>is</span> <span style=''>not</span> <span style=''>yet</span> <span style=''>matched</span> <span style=''>by</span> <span style=''>equal</span> <span style=''>progress</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatic</span> <span style=''>analyses</span> <span style=''>that</span> <span style=''>yield</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>beyond</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameter</span> <span style=''>settings</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>aim</span> <span style=''>to</span> <span style=''>answer</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>following</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>questions</span> <span style=''>Given</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>what</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style=''>its</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style=''>and</span> <span style=''>what</span> <span style=''>are</span> <span style=''>good</span> <span style=''>priors</span> <span style=''>over</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>hyperparameters</span> <span style=''>ranges</span> <span style=''>to</span> <span style=''>draw</span> <span style=''>values</span> <span style=''>from</span> <span style=''>We</span> <span style=''>present</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>answer</span> <span style=''>these</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>questions</span> <span style=''>based</span> <span style=''>on</span> <span style=''>meta</span> <span style=''>learning</span> <span style=''>across</span> <span style=''>many</span> <span style=''>datasets</span> <span style=''>We</span> <span style=''>apply</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>methodology</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>meta</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>on</span> <span style=''>OpenML</span> <span style=''>to</span> <span style ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07407407407407407)
# 	segmentation (0.06481481481481481)
# 	processing (0.10576923076923077)
# 	information (0.24643874643874644)
# 	representation (0.13782051282051283)
# 	experimental (0.14957264957264957)
# 	different (0.26317663817663817)
# 	convolutional (0.12001424501424501)
# 	detection (0.12962962962962962)
# 	recognition (0.12927350427350429)
#
# Some Statistics words are:
# 	algorithms (0.2876506024096386)
# 	stochastic (0.1395582329317269)
# 	variables (0.14006024096385541)
# 	statistical (0.15863453815261044)
# 	distribution (0.1852409638554217)
# 	inference (0.19126506024096385)
# 	estimation (0.178714859437751)
# 	algorithm (0.39206827309236947)
# 	dimensional (0.19477911646586346)
# 	regression (0.1852409638554217)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="24f99dfa-2ab0-48e5-8617-cdda954e88a7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("24f99dfa-2ab0-48e5-8617-cdda954e88a7")) {                    Plotly.newPlot(                        "24f99dfa-2ab0-48e5-8617-cdda954e88a7",                        [{"x":["combining","preserving","introducing","experimental","improving","histopathology","triangular","autoregressive","outperforms","competitive","normalizing","variational","similarly","combination","reduction","inference","difficult","environment","variables","biological","informative","recurrent","algorithms","criterion","according","graphical","signature","bioinformatics","selecting","dimensionality","approaches","applications","probabilities","important","selection","interactive","distinguish","questions","functions","phenomena","recognition","prediction","consuming","expensive","performance","heterogeneity","tomography","component","unlabeled","characterization","annotation","automatic","including","consistently","diagnosis","indicates","motivated","detection","challenging","instances","convolutional","development","specifically","computing","utilizing","contribution","implementing","outperformed","increasing","framework","analytics","contemporary","quantification","objective","multivariate","demonstrate","benchmark","performing","advancement","convergence","estimator","literature","outperform","estimators","sentiments","theoretical","optimizing","extensive","supervised","experiments","stochastic","prevalence","distribution","significantly","population","epidemiology","techniques","estimation","classification","optimization","sentiment","significant","analytical","experiment","simulations","situations","evaluation","influence","necessary","reliability","organizing","available","attaining","uncertainty","similarity","assigning","calculated","introduce","assessing","microarray","relevance","currently","reasonably","procedure","processing","measurements","performed","sensitive","resources","contextual","generative","simultaneously","particular","algorithm","interaction","biomedical","interpretable","maximization","exploration","approximate","information","calculate","parameters","interactions","developed","approximations","application","exploitation","distributions","reinforcement","dependent","limitations","complexity","engineering","properties","facilitates","sequentially","community","optimality","modifications","partially","convexity","numerical","characterised","inequality","intervals","described","constraints","additional","considered","reconstruction","deblurring","imperfect","practically","fingerprints","factorization","measurement","injection","dimensional","therefore","characterized","incorporate","researchers","specially","interested","understanding","different","compounds","separating","overcoming","conducting","representative","solutions","competitively","computational","seriously","carefully","implementation","additionally","modification","excessive","searching","flexibility","generated","validation","principled","attracting","prominent","implement","companies","scientific","capturing","pertaining","efficiency","availability","represents","algebraic","conventional","proximity","efficient","extraction","elementary","unsupervised","dictionaries","denoising","technique","meaningful","vectorizes","convolution","structures","combinations","destructs","comparison","nonlinear","theoretic","structured","markovian","associated","independent","sufficient","asymptotic","conditions","observation","expressions","predicting","conditioned","regression","applicability","successfully","establish","observations","conditionally","characterize","aforementioned","following","recovering","fund ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	nonparanormal
# 	proportionally
# 	predictivity
# 	sylvester
# 	refitting
# 	quantifiable
# 	sufficiency
# 	concordance
# 	thetastar
# 	specialize
# 	subsampling
# 	subsample
# 	differentiation
# 	endmember
# 	eliminated
# 	epidemics
# 	signaling
# 	instabilities
# 	selectors
# 	proprietary
# Some words which never appear in Statistics papers:
# 	characterised
# 	deblurring
# 	vectorizes
# 	destructs
# 	avoidance
# 	accessibility
# 	submissions
# 	participated
# 	categorial
# 	grammatical
# 	syntactic
# 	satisfiability
# 	reachability
# 	undecidable
# 	constancy
# 	propositions
# 	vietnamese
# 	operative
# 	radiography
# 	autonomously

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.064194882794546e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7583333333333333
